# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://raw.githubusercontent.com/meet-vasita/Car-Sales-EDA-Casestudy/refs/heads/main/Dataset/Car_Sales.csv'
df = pd.read_csv(url)

# %%
df.sample(frac=1)
# Out:
#            Make            Model  Year             Engine Fuel Type  \
# 11315     Buick           Verano  2016             regular unleaded
# 10174    Toyota           Tacoma  2015             regular unleaded
# 1282      Honda           Accord  2017             regular unleaded
# 1718      Mazda  B-Series Pickup  2000     flex-fuel (unleaded/E85)
# 8695      Mazda             RX-7  1993             regular unleaded
# ...         ...              ...   ...                          ...
# 10342       GMC          Terrain  2015             regular unleaded
# 8638       Audi             RS 5  2015  premium unleaded (required)
# 3194   Cadillac        CTS Coupe  2012             regular unleaded
# 4752   Cadillac        Fleetwood  1996             regular unleaded
# 7432    Porsche         Panamera  2016  premium unleaded (required)
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 11315      180.0               4.0         AUTOMATIC  front wheel drive
# ...

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.isnull().sum().plot(kind='barh',color='red')
plt.title('Missing Value Information')
# Out:
# Text(0.5, 1.0, 'Missing Value Information')

# %%
#Calculate

df[df['Make'] == 'BMW']
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
df[df['Make'] == 'BMW']['Year'].value_counts().plot(kind='bar',color='maroon')
plt.title('BMW Year')
# Out:
# Text(0.5, 1.0, 'BMW Year')

# %%
df[df['Make'] == 'BMW']['Year'].value_counts()[:5].plot(kind='bar',color='maroon')
plt.title('BMW Year')
# Out:
# Text(0.5, 1.0, 'BMW Year')

# %%
# df[df['Make'] == 'BMW']['MSRP'] <= 50000
# df[(df['Make'] == 'BMW') & (df['MSRP'] <= 50000)]

df[df['MSRP'] <= 50000]['Make'].value_counts()
# Out:
# Make
# Chevrolet        1009
# Ford              816
# Volkswagen        784
# Toyota            719
# Dodge             600
# Nissan            541
# GMC               459
# Honda             449
# Mazda             423
# Suzuki            351
# Hyundai           295
# Volvo             262
# Subaru            256
# Infiniti          244
# Kia               227
# Mitsubishi        213
# Acura             204
# Buick             196
# Audi              195
# Chrysler          187
# Pontiac           186
# Cadillac          177
# BMW               152
# Oldsmobile        150
# Mercedes-Benz     143
# Lexus             134
# Lincoln           131
# Saab              110
# Plymouth           82
# FIAT               62
# Land Rover         61
# Scion              60
# HUMMER             17
# Porsche            15
# Lotus               3
# Genesis             2
# Name: count, dtype: int64

# %%
df[df['city mpg'] == 137]
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5790  BMW    i3  2015         electric      170.0               0.0
# 5791  BMW    i3  2016         electric      170.0               0.0
# 5792  BMW    i3  2017         electric      170.0               0.0
#
#      Transmission Type     Driven_Wheels  Number of Doors   Market Category  \
# 5790      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5791      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5792      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 5790      Compact  4dr Hatchback          111       137        3916  42400
# 5791      Compact  4dr Hatchback          111       137        3916  42400
# 5792      Compact  4dr Hatchback          111       137        3916  42400

# %%
df['highway MPG'].max()
# Out:
# np.int64(354)

# %%
df[df['highway MPG'] == 354]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#      Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1119          Luxury      Midsize         Sedan          354        24
#
#       Popularity   MSRP
# 1119        3105  51600

# %%
df[df['Popularity'] > 3000]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df['Vehicle Size'].value_counts().plot(kind='pie',autopct='%.2f',explode=[0.01,0.01,0.01])
plt.title('Vehicle Size')
# Out:
# Text(0.5, 1.0, 'Vehicle Size')

# %%
Compact = df[df['Vehicle Size'] == 'Compact']

# %%
Midsize = df[df['Vehicle Size'] == 'Midsize']

# %%
Large = df[df['Vehicle Size'] == 'Large']

# %%
Compact['Transmission Type'].value_counts()
# Out:
# Transmission Type
# MANUAL              2173
# AUTOMATIC           2124
# AUTOMATED_MANUAL     416
# DIRECT_DRIVE          45
# UNKNOWN                6
# Name: count, dtype: int64

# %%
df['Engine Fuel Type'].mode()
# Out:
# 0    regular unleaded
# Name: Engine Fuel Type, dtype: object

# %%
df['Engine Fuel Type'].fillna('regular unleaded', inplace = True)

# %%
df['Engine HP'].quantile(0.75),df['Engine HP'].quantile(0.25)
# Out:
# (np.float64(300.0), np.float64(170.0))

# %%
df['Engine Cylinders'].value_counts()
# Out:
# Engine Cylinders
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: count, dtype: int64

# %%
df[df['Engine Cylinders'].isnull()]['Engine Fuel Type'].value_counts()
# Out:
# Engine Fuel Type
# premium unleaded (required)    17
# electric                       10
# regular unleaded                3
# Name: count, dtype: int64

# %%
df['Engine Cylinders'].fillna(4.0, inplace = True)
